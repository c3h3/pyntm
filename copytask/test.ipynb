# %%
import numpy as np
import theano

import sys
sys.path.append('..')

import cPickle as pickle

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm

import tasks
# Out:
# Using gpu device 0: GeForce GTX 650 Ti

# %%
def plot(model, seq_length):
    i,o = tasks.copy(8,seq_length)
    weights,outputs = model.predict(i)

    plt.figure(1,figsize=(20,7))
    plt.subplot(311)
    plt.imshow(i.T,interpolation='nearest')
    plt.subplot(312)
    plt.imshow(o.T,interpolation='nearest')
    plt.subplot(313)
    plt.imshow(outputs.T,interpolation='nearest')


def plot_weights(model, seq_length):
    i,o = tasks.copy(8,seq_length)
    weights,outputs = model.predict(i)

    plt.figure(1,figsize=(20,20))
    plt.imshow(weights.T[100:123],interpolation='nearest',cmap=cm.gray)

# %%
# %time model = pickle.load(open('./model_check.pkl','rb'))
# Out:
# CPU times: user 1min 50s, sys: 2.45 s, total: 1min 52s
# Wall time: 1min 53s

# %%
plot(model, 10)

# %%
plot(model, 20)

# %%
plot(model, 50)

# %%
plot(model, 100)

# %%
plot_weights(model, 100)
